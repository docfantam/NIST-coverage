# %%
import os
import numpy as np
import pandas as pd
import itertools
import json

# %%
path = './logs/'
files = np.array(os.listdir(path))

# %%
pval = np.array([np.genfromtxt(path + file) for file in files])
pval = np.stack(pval) # convert np array of np arrays to 2d np ndarray

M = pval >= 0.01 # pass-fail matrix (, 100000)

# %%
# defining constants
tests = np.array([file[:-len('.txt')] for file in files])
alpha = 0.01
ntests = M.shape[0]
nseqs = M.shape[1]
exp_coverage = np.array([1 - (1 - alpha)**k for k in range(ntests+1)])

# %%
F = np.zeros([ntests, ntests], dtype=float)
for i in range(ntests-1):
    for j in range(i+1, ntests):
        F[i][j] = F[j][i] = np.count_nonzero(~(M[i] | M[j])) # failed both (De Morgan's Law)
        
for i in range(ntests):
    F[i] = F[i] / (np.size(M[i]) - np.count_nonzero(M[i]))

# %%
# Fail-fail ratio table
FFR = pd.DataFrame(F, index = tests, columns = tests, dtype = float)
FFR.to_csv('fail_fail_ratio.csv')
FFR
# Out:
#                            NonOverlappingTemplate84  \
# NonOverlappingTemplate84                   0.000000
# NonOverlappingTemplate125                  0.013345
# NonOverlappingTemplate113                  0.006278
# NonOverlappingTemplate35                   0.010840
# NonOverlappingTemplate127                  0.010870
# ...                                             ...
# RandomExcursions7                          0.011514
# NonOverlappingTemplate70                   0.010480
# RandomExcursionsVariant8                   0.011541
# NonOverlappingTemplate79                   0.015413
# NonOverlappingTemplate118                  0.014978
#
#                            NonOverlappingTemplate125  \
# NonOverlappingTemplate84                    0.013477
# NonOverlappingTemplate125                   0.000000
# NonOverlappingTemplate113                   0.007175
# NonOverlappingTemplate35                    0.014453
# NonOverlappingTemplate127                   0.011775
# ...                                              ...
# RandomExcursions7                           0.011312
# NonOverlappingTemplate70                    0.010480
# RandomExcursionsVariant8                    0.011236
# NonOverlappingTemplate79                    0.017226
# NonOverlappingTemplate118                   0.007930
#
#                            NonOverlappingTemplate113  \
# NonOverlappingTemplate84                    0.006289
# NonOverlappingTemplate125                   0.007117
# NonOverlappingTemplate113                   0.000000
# NonOverlappingTemplate35                    0.007227
# NonOverlappingTemplate127                   0.007246
# ...                                              ...
# RandomExcursions7                           0.011109
# NonOverlappingTemplate70                    0.010480
# RandomExcursionsVariant8                    0.011109
# NonOverlappingTemplate79                    0.019039
# NonOverlappingTemplate118                   0.010573
#
#                            NonOverlappingTemplate35  \
# NonOverlappingTemplate84                   0.010782
# NonOverlappingTemplate125                  0.014235
# NonOverlappingTemplate113                  0.007175
# NonOverlappingTemplate35                   0.000000
# NonOverlappingTemplate127                  0.009964
# ...                                             ...
# RandomExcursions7                          0.011135
# NonOverlappingTemplate70                   0.009607
# RandomExcursionsVariant8                   0.011186
# NonOverlappingTemplate79                   0.013599
# NonOverlappingTemplate118                  0.008811
#
#                            NonOverlappingTemplate127  NonOverlappingTemplate7  \
# NonOverlappingTemplate84                    0.010782                 0.010782
# NonOverlappingTemplate125                   0.011566                 0.008007
# NonOverlappingTemplate113                   0.007175                 0.017040
# NonOverlappingTemplate35                    0.009937                 0.016260
# NonOverlappingTemplate127                   0.000000                 0.012681
# ...                                              ...                      ...
# RandomExcursions7                           0.010907                 0.011869
# NonOverlappingTemplate70                    0.010480                 0.010480
# RandomExcursionsVariant8                    0.010983                 0.011820
# NonOverlappingTemplate79                    0.006346                 0.009973
# NonOverlappingTemplate118                   0.008811                 0.009692
#
#                            NonOverlappingTemplate52  OverlappingTemplate  \
# NonOverlappingTemplate84                   0.011680             0.010782
# NonOverlappingTemplate125                  0.014235             0.010676
# NonOverlappingTemplate113                  0.010762             0.016143
# NonOverlappingTemplate35                   0.013550             0.015357
# NonOverlappingTemplate127                  0.015399             0.015399
# ...                                             ...                  ...
# RandomExcursions7                          0.011034             0.012856
# NonOverlappingTemplate70                   0.018341             0.013100
# RandomExcursionsVariant8                   0.010805             0.012809
# NonOverlappingTemplate79                   0.010879             0.013599
# NonOverlappingTemplate118                  0.009692             0.012335
#
#                            NonOverlappingTemplate134  \
# NonOverlappingTemplate84                    0.008086
# NonOverlappingTemplate125                   0.008897
# NonOverlappingTemplate113                   0.008072
# NonOverlappingTemplate35                    0.011743
# NonOverlappingTemplate127                   0.011775
# ...                                              ...
# RandomExcursions7                           0.011666
# NonOverlappingTemplate70                    0.008734
# RandomExcursionsVariant8                    0.011566
# NonOverlappingTemplate79                    0.009066
# NonOverlappingTemplate118                   0.012335
#
#                            NonOverlappingTemplate12  ...  \
# NonOverlappingTemplate84                   0.014376  ...
# NonOverlappingTemplate125                  0.005338  ...
# NonOverlappingTemplate113                  0.014350  ...
# NonOverlappingTemplate35                   0.010840  ...
# NonOverlappingTemplate127                  0.009964  ...
# ...                                             ...  ...
# RandomExcursions7                          0.011995  ...
# NonOverlappingTemplate70                   0.018341  ...
# RandomExcursionsVariant8                   0.011946  ...
# NonOverlappingTemplate79                   0.014506  ...
# NonOverlappingTemplate118                  0.008811  ...
#
#                            NonOverlappingTemplate11  \
# NonOverlappingTemplate84                   0.009883
# NonOverlappingTemplate125                  0.006228
# NonOverlappingTemplate113                  0.012556
# NonOverlappingTemplate35                   0.015357
# NonOverlappingTemplate127                  0.008152
# ...                                             ...
# RandomExcursions7                          0.011287
# NonOverlappingTemplate70                   0.010480
# RandomExcursionsVariant8                   0.011160
# NonOverlappingTemplate79                   0.009066
# NonOverlappingTemplate118                  0.007048
#
#                            NonOverlappingTemplate138  \
# NonOverlappingTemplate84                    0.014376
# NonOverlappingTemplate125                   0.014235
# NonOverlappingTemplate113                   0.004484
# NonOverlappingTemplate35                    0.012647
# NonOverlappingTemplate127                   0.013587
# ...                                              ...
# RandomExcursions7                           0.010527
# NonOverlappingTemplate70                    0.008734
# RandomExcursionsVariant8                    0.010754
# NonOverlappingTemplate79                    0.004533
# NonOverlappingTemplate118                   0.008811
#
#                            NonOverlappingTemplate129  \
# NonOverlappingTemplate84                    0.015274
# NonOverlappingTemplate125                   0.008897
# NonOverlappingTemplate113                   0.010762
# NonOverlappingTemplate35                    0.013550
# NonOverlappingTemplate127                   0.012681
# ...                                              ...
# RandomExcursions7                           0.010983
# NonOverlappingTemplate70                    0.009607
# RandomExcursionsVariant8                    0.011059
# NonOverlappingTemplate79                    0.010879
# NonOverlappingTemplate118                   0.018502
#
#                            RandomExcursionsVariant11  \
# NonOverlappingTemplate84                    0.412399
# NonOverlappingTemplate125                   0.392349
# NonOverlappingTemplate113                   0.391031
# NonOverlappingTemplate35                    0.397471
# NonOverlappingTemplate127                   0.395833
# ...                                              ...
# RandomExcursions7                           0.984614
# NonOverlappingTemplate70                    0.383406
# RandomExcursionsVariant8                    0.985314
# NonOverlappingTemplate79                    0.391659
# NonOverlappingTemplate118                   0.375330
#
#                            NonOverlappingTemplate68  RandomExcursions7  \
# NonOverlappingTemplate84                   0.017071           0.408805
# NonOverlappingTemplate125                  0.006228           0.397687
# NonOverlappingTemplate113                  0.017040           0.393722
# NonOverlappingTemplate35                   0.008130           0.397471
# NonOverlappingTemplate127                  0.011775           0.390399
# ...                                             ...                ...
# RandomExcursions7                          0.010603           0.000000
# NonOverlappingTemplate70                   0.010480           0.385153
# RandomExcursionsVariant8                   0.010602           0.985213
# NonOverlappingTemplate79                   0.010879           0.385313
# NonOverlappingTemplate118                  0.015859           0.376211
#
#                            NonOverlappingTemplate70  RandomExcursionsVariant8  \
# NonOverlappingTemplate84                   0.010782                  0.408805
# NonOverlappingTemplate125                  0.010676                  0.394128
# NonOverlappingTemplate113                  0.010762                  0.392825
# NonOverlappingTemplate35                   0.009937                  0.398374
# NonOverlappingTemplate127                  0.010870                  0.392210
# ...                                             ...                       ...
# RandomExcursions7                          0.011160                  0.982969
# NonOverlappingTemplate70                   0.000000                  0.384279
# RandomExcursionsVariant8                   0.011160                  0.000000
# NonOverlappingTemplate79                   0.020852                  0.388939
# NonOverlappingTemplate118                  0.009692                  0.373568
#
#                            NonOverlappingTemplate79  NonOverlappingTemplate118
# NonOverlappingTemplate84                   0.015274                   0.015274
# NonOverlappingTemplate125                  0.016904                   0.008007
# NonOverlappingTemplate113                  0.018834                   0.010762
# NonOverlappingTemplate35                   0.013550                   0.009033
# NonOverlappingTemplate127                  0.006341                   0.009058
# ...                                             ...                        ...
# RandomExcursions7                          0.010755                   0.010806
# NonOverlappingTemplate70                   0.020087                   0.009607
# RandomExcursionsVariant8                   0.010881                   0.010754
# NonOverlappingTemplate79                   0.000000                   0.013599
# NonOverlappingTemplate118                  0.013216                   0.000000
#
# [188 rows x 188 columns]

# %%
def cov(subset):
    # sequences that pass all tests
    pass_all = np.ones((nseqs), dtype=bool)
    for test in subset:
        pass_all = pass_all & M[test]

    # calculate coverage
    coverage = np.count_nonzero(~pass_all)/nseqs
    return coverage

# %%
rows_list = []

# considering all tests
total_coverage = cov(range(ntests))

# excluding one test at a time
for subset in itertools.combinations(range(ntests), ntests-1): # excluding one test at a time
    test_idx = sum(range(ntests)) - sum(subset)
    test = tests[test_idx]
    
    coverage = cov(subset)
    benefit = total_coverage - coverage
    
    # add row
    rows_list.append({'Test': test, 'MarginalBenefit': benefit})

# %%
# Marginal Benefits
MB = pd.DataFrame(rows_list, columns=['Test', 'MarginalBenefit'])
MB = MB.sort_values(by=['MarginalBenefit'], ascending=False)
MB = MB.set_index('Test')
MB.to_csv('marginal_benefits.csv')
MB
# Out:
#                            MarginalBenefit
# Test
# Serial1                            0.01261
# Serial2                            0.00296
# ApproximateEntropy                 0.00128
# NonOverlappingTemplate5            0.00108
# OverlappingTemplate                0.00104
# ...                                    ...
# NonOverlappingTemplate74           0.00001
# Frequency                          0.00001
# NonOverlappingTemplate75           0.00000
# NonOverlappingTemplate1            0.00000
# NonOverlappingTemplate148          0.00000
#
# [188 rows x 1 columns]

# %%
rows_list = []

# change accordingly
MAX_SUBSET_SIZE = 5

for k in range(2, MAX_SUBSET_SIZE):
    max_coverage = 0
    for subset in itertools.combinations(range(ntests), k): # subsets of k tests
        coverage = cov(subset)
        # update max_coverage and max_subset
        if coverage > max_coverage:
            max_coverage = coverage
            max_subset = subset
    
    # update max_efficiency
    max_efficiency = max_coverage/exp_coverage[k]
    
    # add row
    rows_list.append({'k': k, 'Subsuite': tests[list(max_subset)], 'Coverage': max_coverage, 'Efficiency': max_efficiency})
    print(k, "done!")
# Out:
# 2 done!
# 3 done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-205fe1d61c0e> in <module>
#       7     max_coverage = 0
#       8     for subset in itertools.combinations(range(ntests), k): # subsets of k tests
# ----> 9         coverage = cov(subset)
#      10         # update max_coverage and max_subset
#      11         if coverage > max_coverage:
#
# <ipython-input-7-c83d0c142c57> in cov(subset)
#       6
#       7     # calculate coverage
# ----> 8     coverage = np.count_nonzero(~pass_all)/nseqs
#       9     return coverage
#
# KeyboardInterrupt:

# %%
# Most efficient subsuites
MES = pd.DataFrame(rows_list, columns=['k', 'Subsuite', 'Coverage', 'Efficiency'])
MES.to_json('most_efficienct_subsuites.json', orient='records')
MES = MES.set_index('k')
MES
